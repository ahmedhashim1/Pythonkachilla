# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
titanic = sns.load_dataset("titanic")

# %%
os.chdir(r"E:\PythonKaChilla\30-ExploratoryDataAnalysis")
titanic.to_csv("titanic.csv")

# %%
titanic.info
# Out:
# <bound method DataFrame.info of      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
t = titanic
t.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
t.tail(5)
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
t.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
t.nunique()
# Out:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %%
t.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
titanic.concat([titanic['age'], titanic['fare']]).unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 titanic.concat([titanic['age'], titanic['fare']]).unique()
#
# File E:\PythonKaChilla\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'concat'

# %%
#cleaning and filtering data
#find missing values
t.isnull().sum()

# %%
clean_data = t.drop(['deck'], axis =1)
clean_data.head()

# %%
clean_data.isnull().sum()

# %%
clean_data = t
clean_data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
clean_data.drop(['deck'], axis =1)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
clean_data = clean_data.dropna()
clean_data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
clean_data = clean_data.drop(['deck'], axis =1)

# %%
clean_data.head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1          1       1  female  38.0      1      0  71.2833        C  First
# 3          1       1  female  35.0      1      0  53.1000        S  First
# 6          0       1    male  54.0      0      0  51.8625        S  First
# 10         1       3  female   4.0      1      1  16.7000        S  Third
# 11         1       1  female  58.0      0      0  26.5500        S  First
#
#       who  adult_male  embark_town alive  alone
# 1   woman       False    Cherbourg   yes  False
# 3   woman       False  Southampton   yes  False
# 6     man        True  Southampton    no   True
# 10  child       False  Southampton   yes  False
# 11  woman       False  Southampton   yes   True

# %%
clean_data.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
clean_data.shape
# Out:
# (182, 14)

# %%
clean_data['sex'].value_counts()
# Out:
# male      94
# female    88
# Name: sex, dtype: int64

# %%
t.shape
# Out:
# (891, 15)

# %%
clean_data = t
clean_data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
clean_data = clean_data.dropna()

# %%
clean_data.shape
# Out:
# (182, 15)

# %%
t.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
clean_data.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  182.000000  182.000000  182.000000  182.000000  182.000000  182.000000
# mean     0.675824    1.192308   35.623187    0.467033    0.478022   78.919735
# std      0.469357    0.516411   15.671615    0.645007    0.755869   76.490774
# min      0.000000    1.000000    0.920000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   24.000000    0.000000    0.000000   29.700000
# 50%      1.000000    1.000000   36.000000    0.000000    0.000000   57.000000
# 75%      1.000000    1.000000   47.750000    1.000000    1.000000   90.000000
# max      1.000000    3.000000   80.000000    3.000000    4.000000  512.329200

# %%
clean_data.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
sns.boxplot(y='age', data=clean_data)
# Out:
# <Axes: ylabel='age'>

# %%
sns.displot(clean_data['age'])

# %%
#removals of outliers
clean_data['age'].mean()
# Out:
# 35.62318681318681

# %%
clean_data['age'] < 68
# Out:
# 1      True
# 3      True
# 6      True
# 10     True
# 11     True
#        ...
# 871    True
# 872    True
# 879    True
# 887    True
# 889    True
# Name: age, Length: 182, dtype: bool

# %%
clean_data['age'] = clean_data['age'] < 68
clean_data.mean()
# Out:
# C:\Users\ahmed\AppData\Local\Temp\ipykernel_16288\2706288437.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   clean_data.mean()
# survived       0.404494
# pclass         2.240169
# age            1.000000
# sibsp          0.514045
# parch          0.432584
# fare          34.567251
# adult_male     0.580056
# alone          0.564607
# dtype: float64

# %%
clean_data = clean_data[clean_data['age']<68]
clean_data.head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1          1       1  female  38.0      1      0  71.2833        C  First
# 3          1       1  female  35.0      1      0  53.1000        S  First
# 6          0       1    male  54.0      0      0  51.8625        S  First
# 10         1       3  female   4.0      1      1  16.7000        S  Third
# 11         1       1  female  58.0      0      0  26.5500        S  First
#
#       who  adult_male deck  embark_town alive  alone
# 1   woman       False    C    Cherbourg   yes  False
# 3   woman       False    C  Southampton   yes  False
# 6     man        True    E  Southampton    no   True
# 10  child       False    G  Southampton   yes  False
# 11  woman       False    C  Southampton   yes   True

# %%
clean_data.shape
# Out:
# (891, 14)

# %%
clean_data.shape
# Out:
# (712, 14)

# %%
clean_data = clean_data.dropna()

# %%
clean_data = clean_data[clean_data['age']<68]
clean_data.shape
# Out:
# (705, 14)

# %%
clean_data['age'].mean()
# Out:
# 29.21797163120567

# %%
sns.displot(clean_data['age'])

# %%
sns.boxplot(y='age', data=clean_data)
# Out:
# <Axes: ylabel='age'>

# %%
clean_data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %%
clean_data.boxplot()
# Out:
# <Axes: >

# %%
clean_data = clean_data[clean_data['fare']<300]
clean_data.boxplot()
# Out:
# <Axes: >

# %%
sns.displot(clean_data['fare'])

# %%
clean_data.hist()
# Out:
# array([[<Axes: title={'center': 'survived'}>,
#         <Axes: title={'center': 'pclass'}>],
#        [<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'sibsp'}>],
#        [<Axes: title={'center': 'parch'}>,
#         <Axes: title={'center': 'fare'}>]], dtype=object)

# %%
pd.value_counts(clean_data['survived']).plot.bar()
# Out:
# <Axes: >

# %%
clean_data.groupby(['sex', 'class','who']).mean()
# Out:
# C:\Users\ahmed\AppData\Local\Temp\ipykernel_16288\1988913522.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   clean_data.groupby(['sex', 'class','who']).mean()
#                      survived  pclass        age     sibsp     parch  \
# sex    class  who
# female First  child  0.666667     1.0  10.333333  0.666667  1.666667
#               man         NaN     NaN        NaN       NaN       NaN
#               woman  0.974684     1.0  35.139241  0.556962  0.468354
#        Second child  1.000000     2.0   6.600000  0.700000  1.300000
#               man         NaN     NaN        NaN       NaN       NaN
#               woman  0.906250     2.0  32.179688  0.468750  0.515625
#        Third  child  0.533333     3.0   7.100000  1.533333  1.100000
# ...

# %%
#Relationship
corr_clean = clean_data.corr()
corr_clean
# Out:
# C:\Users\ahmed\AppData\Local\Temp\ipykernel_16288\1408034002.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_clean = clean_data.corr()
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.356549 -0.074335 -0.014483  0.095426  0.273531
# pclass     -0.356549  1.000000 -0.365121  0.061354  0.022519 -0.617591
# age        -0.074335 -0.365121  1.000000 -0.308906 -0.186271  0.103100
# sibsp      -0.014483  0.061354 -0.308906  1.000000  0.381803  0.197954
# parch       0.095426  0.022519 -0.186271  0.381803  1.000000  0.259948
# fare        0.273531 -0.617591  0.103100  0.197954  0.259948  1.000000
# adult_male -0.554567  0.102930  0.275035 -0.311622 -0.366540 -0.228675
# alone      -0.201175  0.156030  0.187284 -0.629200 -0.574701 -0.333949
#
# ...

# %%
sns.heatmap(corr_clean)
# Out:
# <Axes: >

# %%
corr_clean
sns.heatmap(corr_clean, annot=True)
# Out:
# <Axes: >

# %%
sns.relplot(x='age', y='fare',hue='sex', data=clean_data)

# %%
sns.catplot(x='sex', y='age',hue='sex', data=clean_data, kind='box')

# %%
#adding column log
clean_data['fare_log'] = np.log(clean_data['fare'])
clean_data
# Out:
# E:\PythonKaChilla\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# ...

# %%
sns.catplot(x='sex', y='fare_log', hue='sex', data=clean_data, kind='box')
